# %% [markdown]
# <a href="https://colab.research.google.com/github/natalie2103/CS103/blob/main/Email_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install mailbox
# Out:
# Collecting mailbox
#   Downloading mailbox-0.4.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mailbox
#   Building wheel for mailbox (setup.py) ... done
#   Created wheel for mailbox: filename=mailbox-0.4-py3-none-any.whl size=4684 sha256=95b8741efcdc35fd1de19482d18410b3ed988e2a9eae89a9b2114079c06c5ff2
#   Stored in directory: /root/.cache/pip/wheels/7a/95/10/e0864f9d19ec7dcdf7eeedcb286ec19fc2556404a5e63e12de
# Successfully built mailbox
# Installing collected packages: mailbox
# Successfully installed mailbox-0.4

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import mailbox
mboxfile = "gdrive/My Drive/Colab Notebooks/spamntrash.mbox"

mbox = mailbox.mbox(mboxfile)
mbox

# %%
for key in mbox[0].keys():
  print(key)
# Out:
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# Feedback-Id
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id

# %%
import csv

with open('mailbox.csv', 'w') as outputfile:
  writer = csv.writer(outputfile)
  writer.writerow(['subject','from','date','to','label','thread'])

  for message in mbox:
    writer.writerow([message['subject'], message['from'],  message['date'], message['to'],  message['X-Gmail-Labels'], message['X-GM-THRID']])

# %%
dfs = pd.read_csv('mailbox.csv', names=['subject', 'from', 'date', 'to', 'label', 'thread'])

# %%
dfs.dtypes
# Out:
# subject    object
# from       object
# date       object
# to         object
# label      object
# thread     object
# dtype: object

# %%
dfs['date'] = dfs['date'].apply(lambda x: pd.to_datetime(x, errors='coerce', utc=True))

# %%
dfs = dfs[dfs['date'].notna()]

# %%
dfs.to_csv('gmail.csv')

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 911 entries, 1 to 911
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   subject  748 non-null    object
#  1   from     911 non-null    object
#  2   date     911 non-null    datetime64[ns, UTC]
#  3   to       905 non-null    object
#  4   label    911 non-null    object
#  5   thread   911 non-null    object
# dtypes: datetime64[ns, UTC](1), object(5)
# memory usage: 49.8+ KB

# %%
dfs.head(10)
# Out:
#                                               subject  \
# 1                OpenAI o1 Guide: How It Works & More
# 2   This is your reminder: BER months na, may up t...
# 3                                                 NaN
# 4   ISAT U VLE Notification You have submitted you...
# 5   ISAT U VLE Notification You have upcoming acti...
# 6                                                 Re:
# 7                                                 NaN
# 8   We see winning awesome prizes in your future! ...
# 9   Ano tawag sa sirang can opener? Can't open! - ...
# 10  Action needed: R Programming, Data Preparation...
#
#                                                  from  \
# 1               DataCamp Insights <team@datacamp.com>
# 2               foodpanda <contact@info.foodpanda.ph>
# 3   NATALIE JOY LOREDO <nataliejoy.loredo@students...
# 4   "Do not reply to this email  (via ISAT U VLE)"...
# 5   "ISAT U VLE Admin (via ISAT U VLE)" <noreply@i...
# 6          Natalie Loredo <natalieloredo89@gmail.com>
# 7          Natalie Loredo <natalieloredo89@gmail.com>
# 8               foodpanda <contact@info.foodpanda.ph>
# 9               foodpanda <contact@info.foodpanda.ph>
# 10              The DataCamp Team <team@datacamp.com>
#
#                         date  \
# 1  2024-09-17 15:16:06+00:00
# 2  2024-09-08 02:05:52+00:00
# 3  2024-09-06 07:58:47+00:00
# 4  2024-08-27 10:21:31+00:00
# 5  2024-08-27 07:02:33+00:00
# 6  2024-09-21 10:48:36+00:00
# 7  2024-09-21 10:44:32+00:00
# 8  2024-05-27 10:46:36+00:00
# 9  2024-06-16 02:08:54+00:00
# 10 2024-05-07 01:30:15+00:00
#
#                                                    to  \
# 1             nataliejoy.loredo@students.isatu.edu.ph
# 2             nataliejoy.loredo@students.isatu.edu.ph
# 3          Natalie Loredo <natalieloredo89@gmail.com>
# 4   "NATALIE JOY LOREDO" <nataliejoy.loredo@studen...
# 5   "NATALIE JOY LOREDO" <nataliejoy.loredo@studen...
# 6   NATALIE JOY LOREDO <nataliejoy.loredo@students...
# 7   NATALIE JOY LOREDO <nataliejoy.loredo@students...
# 8             nataliejoy.loredo@students.isatu.edu.ph
# 9             nataliejoy.loredo@students.isatu.edu.ph
# 10            nataliejoy.loredo@students.isatu.edu.ph
#
#                                        label               thread
# 1           Inbox,Category Promotions,Unread  1810456817820445669
# 2           Inbox,Category Promotions,Unread  1809591727753084514
# 3                              Archived,Sent  1809432164568795583
# 4             Inbox,Category Personal,Unread  1808535746924355464
# 5              Spam,Category Personal,Unread  1808523228821168824
# 6   Inbox,Important,Category Personal,Unread  1810802134409620184
# 7   Inbox,Important,Category Personal,Unread  1810802134409620184
# 8           Inbox,Category Promotions,Unread  1800202405747177702
# 9           Inbox,Category Promotions,Unread  1801982883733439623
# 10          Inbox,Category Promotions,Unread  1798355461977123348

# %%
dfs.columns
# Out:
# Index(['subject', 'from', 'date', 'to', 'label', 'thread'], dtype='object')

# %%
import re

def extract_email_ID(string):
  email = re.findall(r'<(.+?)>', string)
  if not email:
    email = list(filter(lambda y: '@' in y, string.split()))
  return email[0] if email else np.nan

# %%
dfs['from'] = dfs['from'].apply(lambda x: extract_email_ID(x))

# %%
myemail = 'nataliejoy.loredo@students.isatu.edu.ph'
dfs['label'] = dfs['from'].apply(lambda x: 'sent' if x==myemail else 'inbox')

# %%
dfs.drop(columns='to', inplace=True)

# %%
dfs.head(10)
# Out:
#                                               subject  \
# 1                OpenAI o1 Guide: How It Works & More
# 2   This is your reminder: BER months na, may up t...
# 3                                                 NaN
# 4   ISAT U VLE Notification You have submitted you...
# 5   ISAT U VLE Notification You have upcoming acti...
# 6                                                 Re:
# 7                                                 NaN
# 8   We see winning awesome prizes in your future! ...
# 9   Ano tawag sa sirang can opener? Can't open! - ...
# 10  Action needed: R Programming, Data Preparation...
#
#                                        from                      date  label  \
# 1                         team@datacamp.com 2024-09-17 15:16:06+00:00  inbox
# 2                 contact@info.foodpanda.ph 2024-09-08 02:05:52+00:00  inbox
# 3   nataliejoy.loredo@students.isatu.edu.ph 2024-09-06 07:58:47+00:00   sent
# 4                   noreply@isatuvle.online 2024-08-27 10:21:31+00:00  inbox
# 5                   noreply@isatuvle.online 2024-08-27 07:02:33+00:00  inbox
# 6                 natalieloredo89@gmail.com 2024-09-21 10:48:36+00:00  inbox
# 7                 natalieloredo89@gmail.com 2024-09-21 10:44:32+00:00  inbox
# 8                 contact@info.foodpanda.ph 2024-05-27 10:46:36+00:00  inbox
# 9                 contact@info.foodpanda.ph 2024-06-16 02:08:54+00:00  inbox
# 10                        team@datacamp.com 2024-05-07 01:30:15+00:00  inbox
#
#                  thread
# 1   1810456817820445669
# 2   1809591727753084514
# 3   1809432164568795583
# 4   1808535746924355464
# 5   1808523228821168824
# 6   1810802134409620184
# 7   1810802134409620184
# 8   1800202405747177702
# 9   1801982883733439623
# 10  1798355461977123348

# %%
import datetime
import pytz

def refactor_timezone(x):
  est = pytz.timezone('US/Eastern')
  return x.astimezone(est)

# %%
dfs['date'] = dfs['date'].apply(lambda x: refactor_timezone(x))

# %%
dfs['dayofweek'] = dfs['date'].apply(lambda x: x.day_name()) # Use day_name() to get the day of the week
dfs['dayofweek'] = pd.Categorical(dfs['dayofweek'], categories=[
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
    'Saturday', 'Sunday'], ordered=True)

# %%
dfs['timeofday'] = dfs['date'].apply(lambda x: x.hour + x.minute/60 + x.second/3600)

# %%
dfs['hour'] = dfs['date'].apply(lambda x: x.hour)

# %%
dfs['year_int'] = dfs['date'].apply(lambda x: x.year)

# %%
dfs['year'] = dfs['date'].apply(lambda x: x.year + x.dayofyear/365.25)

# %%
dfs.index = dfs['date']
del dfs['date']

# %%
print(dfs.index.min().strftime('%a, %d %b %Y %I:%M %p'))
print(dfs.index.max().strftime('%a, %d %b %Y %I:%M %p'))

print(dfs['label'].value_counts())
# Out:
# Tue, 23 Aug 2022 09:52 PM
# Wed, 25 Sep 2024 08:17 PM
# label
# inbox    736
# sent     175
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
def plot_todo_vs_year(df, ax, color='C0', s=0.5, title=''):
  ind = np.zeros(len(df), dtype='bool')
  est = pytz.timezone('US/Eastern')

  df[~ind].plot.scatter('year', 'timeofday', s=s, alpha=0.6, ax=ax, color=color)
  ax.set_ylim(0, 24)
  ax.yaxis.set_major_locator(MaxNLocator(8))
  ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);

  ax.set_xlabel('')
  ax.set_ylabel('')
  ax.set_title(title)
  ax.grid(ls=':', color='k')

  return ax

# %%
sent = dfs[dfs['label']=='sent']
received = dfs[dfs['label']=='inbox']

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))

plot_todo_vs_year(sent, ax[0], title='Sent')
plot_todo_vs_year(received, ax[1], title='Received')
# Out:
# <ipython-input-31-725e438063d6>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);
# <ipython-input-31-725e438063d6>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);
# <Axes: title={'center': 'Received'}>

# %%
def plot_number_perday_per_year(df, ax, label=None, dt=0.3, **plot_kwargs):
    year = df[df['year'].notna()]['year'].values
    T = year.max() - year.min()
    bins = int(T / dt)
    weights = 1 / (np.ones_like(year) * dt * 365.25)
    ax.hist(year, bins=bins, weights=weights, label=label, **plot_kwargs);
    ax.grid(ls=':', color='k')

# %%
from scipy import ndimage

def plot_number_perdhour_per_year(df, ax, label=None, dt=1, smooth=False,
                      weight_fun=None, **plot_kwargs):

    tod = df[df['timeofday'].notna()]['timeofday'].values
    year = df[df['year'].notna()]['year'].values
    Ty = year.max() - year.min()
    T = tod.max() - tod.min()
    bins = int(T / dt)
    if weight_fun is None:
        weights = 1 / (np.ones_like(tod) * Ty * 365.25 / dt)
    else:
        weights = weight_fun(df)
    if smooth:
        hst, xedges = np.histogram(tod, bins=bins, weights=weights);
        x = np.delete(xedges, -1) + 0.5*(xedges[1] - xedges[0])
        hst = ndimage.gaussian_filter(hst, sigma=0.75)
        f = interp1d(x, hst, kind='cubic')
        x = np.linspace(x.min(), x.max(), 10000)
        hst = f(x)
        ax.plot(x, hst, label=label, **plot_kwargs)
    else:
        ax.hist(tod, bins=bins, weights=weights, label=label, **plot_kwargs);


    ax.grid(ls=':', color='k')
    orientation = plot_kwargs.get('orientation')
    if orientation is None or orientation == 'vertical':
        ax.set_xlim(0, 24)
        ax.xaxis.set_major_locator(MaxNLocator(8))
        ax.set_xticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")
                            for ts in ax.get_xticks()]);
    elif orientation == 'horizontal':
        ax.set_ylim(0, 24)
        ax.yaxis.set_major_locator(MaxNLocator(8))
        ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")
                            for ts in ax.get_yticks()]);

# %%
class TriplePlot:
  def __init__(self):
    gs = gridspec.GridSpec(6, 6)
    self.ax1 = plt.subplot(gs[2:6, :4])
    self.ax2 = plt.subplot(gs[2:6, 4:6], sharey=self.ax1)
    plt.setp(self.ax2.get_yticklabels(), visible=False);
    self.ax3 = plt.subplot(gs[:2, :4])
    plt.setp(self.ax3.get_xticklabels(), visible=False);

  def plot(self, df, color='darkblue', alpha=0.8, markersize=0.5, yr_bin=0.1, hr_bin=0.5):
    plot_todo_vs_year(df, self.ax1, color=color, s=markersize)
    plot_number_perdhour_per_year(df, self.ax2, dt=hr_bin, color=color, alpha=alpha, orientation='horizontal')
    self.ax2.set_xlabel('Average emails per hour')
    plot_number_perday_per_year(df, self.ax3, dt=yr_bin, color=color, alpha=alpha)
    self.ax3.set_ylabel('Average emails per day')

# %%
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

plt.figure(figsize=(12,12));
tpl = TriplePlot()

tpl.plot(received, color='C0', alpha=0.5)
tpl.plot(sent, color='C1', alpha=0.5)
p1 = mpatches.Patch(color='C0', label='Incoming', alpha=0.5)
p2 = mpatches.Patch(color='C1', label='Outgoing', alpha=0.5)
plt.legend(handles=[p1, p2], bbox_to_anchor=[1.45, 0.7], fontsize=14, shadow=True);
# Out:
# <ipython-input-31-725e438063d6>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);
# <ipython-input-35-fe9fa0c6dab1>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")
# <ipython-input-31-725e438063d6>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);
# <ipython-input-35-fe9fa0c6dab1>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")

# %%
counts = dfs.dayofweek.value_counts(sort=False)
counts.plot(kind='bar')
# Out:
# <Axes: xlabel='dayofweek'>

# %%
addrs = received['from'].value_counts()

addrs[0:4]
# Out:
# from
# contact@info.foodpanda.ph          179
# notification@service.tiktok.com    112
# team@datacamp.com                   75
# no-reply@accounts.google.com        75
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,12));

tpl = TriplePlot()

labels = []
colors = ['C{}'.format(ii) for ii in range(9)]
idx = np.array([1,2,3,7])
for ct, addr in enumerate(addrs.index[idx]):
    tpl.plot(dfs[dfs['from'] == addr], color=colors[ct], alpha=0.3, yr_bin=0.5, markersize=1.0)
    labels.append(mpatches.Patch(color=colors[ct], label=addrs[0:4], alpha=0.5))
plt.legend(handles=labels, bbox_to_anchor=[1.4, 0.9], fontsize=12, shadow=True);
# Out:
# <ipython-input-31-725e438063d6>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);
# <ipython-input-35-fe9fa0c6dab1>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")
# <ipython-input-31-725e438063d6>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);
# <ipython-input-35-fe9fa0c6dab1>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-264606d9c6b8> in <cell line: 8>()
#       7 idx = np.array([1,2,3,7])
#       8 for ct, addr in enumerate(addrs.index[idx]):
# ----> 9     tpl.plot(dfs[dfs['from'] == addr], color=colors[ct], alpha=0.3, yr_bin=0.5, markersize=1.0)
#      10     labels.append(mpatches.Patch(color=colors[ct], label=addrs[0:4], alpha=0.5))
#      11 plt.legend(handles=labels, bbox_to_anchor=[1.4, 0.9], fontsize=12, shadow=True);
#
# <ipython-input-36-e80e8dd8fba7> in plot(self, df, color, alpha, markersize, yr_bin, hr_bin)
#      12     plot_number_perdhour_per_year(df, self.ax2, dt=hr_bin, color=color, alpha=alpha, orientation='horizontal')
#      13     self.ax2.set_xlabel('Average emails per hour')
# ---> 14     plot_number_perday_per_year(df, self.ax3, dt=yr_bin, color=color, alpha=alpha)
#      15     self.ax3.set_ylabel('Average emails per day')
#
# <ipython-input-34-3a24ed20dcae> in plot_number_perday_per_year(df, ax, label, dt, **plot_kwargs)
#       4     bins = int(T / dt)
#       5     weights = 1 / (np.ones_like(year) * dt * 365.25)
# ----> 6     ax.hist(year, bins=bins, weights=weights, label=label, **plot_kwargs);
#       7     ax.grid(ls=':', color='k')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6788             # this will automatically overwrite bins,
#    6789             # so that each histogram uses the same bins
# -> 6790             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6791             tops.append(m)
#    6792         tops = np.array(tops, float)  # causes problems later if it's an int
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/histograms.py in histogram(a, bins, range, density, weights)
#     778     a, weights = _ravel_and_check_weights(a, weights)
#     779
# --> 780     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     781
#     782     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     422                 '`bins` must be an integer, a string, or an array') from e
#     423         if n_equal_bins < 1:
# --> 424             raise ValueError('`bins` must be positive, when an integer')
#     425
#     426         first_edge, last_edge = _get_outer_edges(a, range)
#
# ValueError: `bins` must be positive, when an integer

# %%
sdw = sent.groupby('dayofweek').size() / len(sent)
rdw = received.groupby('dayofweek').size() / len(received)

df_tmp = pd.DataFrame(data={'Outgoing Email': sdw, 'Incoming Email':rdw})
df_tmp.plot(kind='bar', rot=45, figsize=(8,5), alpha=0.5)
plt.xlabel('');
plt.ylabel('Fraction of weekly emails');
plt.grid(ls=':', color='k', alpha=0.5)
# Out:
# <ipython-input-52-c5abe68ebf9d>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sdw = sent.groupby('dayofweek').size() / len(sent)
# <ipython-input-52-c5abe68ebf9d>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rdw = received.groupby('dayofweek').size() / len(received)

# %%
import scipy.ndimage
from scipy.interpolate import interp1d

plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for ct, dow in enumerate(dfs.dayofweek.cat.categories):
    df_r = received[received['dayofweek']==dow]
    weights = np.ones(len(df_r)) / len(received)
    wfun = lambda x: weights
    plot_number_perdhour_per_year(df_r, ax, dt=1, smooth=True, color=f'C{ct}',
                      alpha=0.8, lw=3, label=dow, weight_fun=wfun)

    df_s = sent[sent['dayofweek']==dow]
    weights = np.ones(len(df_s)) / len(sent)
    wfun = lambda x: weights
    plot_number_perdhour_per_year(df_s, ax, dt=1, smooth=True, color=f'C{ct}',
                      alpha=0.8, lw=2, label=dow, ls='--', weight_fun=wfun)
ax.set_ylabel('Fraction of weekly emails per hour')
plt.legend(loc='upper left')
# Out:
# <ipython-input-35-fe9fa0c6dab1>:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")

# %%
from wordcloud import WordCloud

df_no_arxiv = dfs[dfs['from'] != 'no-reply@arXiv.org']
text = ' '.join(map(str, sent['subject'].values))

# %%
stopwords = ['Re', 'Fwd', '3A_']
wrd = WordCloud(width=700, height=480, margin=0, collocations=False)
for sw in stopwords:
    wrd.stopwords.add(sw)
wordcloud = wrd.generate(text)

plt.figure(figsize=(25,15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
